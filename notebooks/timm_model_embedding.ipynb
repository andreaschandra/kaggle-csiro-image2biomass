# %%
import numpy as np
import timm
from PIL import Image

# %%
x = np.random.randint(0, 255, size=(10, 500, 500, 3), dtype=np.uint8)

# %%
x_pil = Image.fromarray(x[0])

# %%
data_config = timm.data.resolve_model_data_config("convnextv2_huge.fcmae_ft_in22k_in1k_512")
transform = timm.data.create_transform(**data_config, is_training=False)

# %%
transform(x_pil)
# Out:
# tensor([[[-0.9705,  0.2967,  0.0227,  ..., -0.0287,  0.5364,  0.1426],
#          [-0.8164,  0.0741,  0.1083,  ...,  1.1187,  0.1426,  0.1768],
#          [-0.6623, -0.0629,  0.8104,  ...,  0.1768,  0.7762,  0.5536],
#          ...,
#          [ 1.0331,  0.5364,  0.1083,  ...,  0.4166,  0.4166,  0.4166],
#          [ 0.4508,  0.5193,  0.0398,  ..., -0.1999,  0.7248, -0.0116],
#          [-0.2684, -0.9192, -0.4568,  ..., -0.6794,  0.3309,  0.9303]],
#
#         [[-0.0224,  0.3803, -0.1450,  ..., -0.8277,  0.5553,  0.9230],
#          [ 0.2227,  0.4153, -0.2325,  ...,  0.2402,  0.0826,  0.0126],
#          [ 0.8529,  0.5378,  0.0126,  ..., -0.1800,  0.1176, -1.1604],
#          ...,
#          [-0.1099,  1.1506,  0.6429,  ...,  0.2227, -0.3025,  0.2402],
#          [ 0.6254,  0.2577,  0.3102,  ...,  0.4853,  1.2731, -0.1800],
#          [ 0.0126, -0.3375,  0.2052,  ..., -0.1800,  0.2402,  0.2227]],
#
#         [[ 0.3742, -0.1138, -0.7238,  ...,  0.6356,  0.3393, -0.5670],
#          [ 0.4788,  0.1476,  0.7751,  ...,  0.6531, -0.3230, -0.4101],
#          [ 0.7925,  0.7576,  1.1237,  ...,  0.6531, -0.0092, -0.5495],
#          ...,
#          [ 0.4962,  0.5311,  0.9145,  ...,  0.0431, -1.0027,  0.1651],
#          [ 0.1825,  0.6182,  0.2696,  ...,  0.6008,  0.0953,  1.0714],
#          [ 0.7054,  0.8099,  0.0779,  ...,  0.2871,  0.8274,  0.7402]]])
